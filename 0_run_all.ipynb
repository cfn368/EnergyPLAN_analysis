# %% [markdown]
# *Run all*

# %%
print(f'The norwegians O&M is {0.0182 * 6.18:.2f}MEUR/MW, while ours is {0.0520 * 4.3:.2f} MEUR/MW')
# Out:
# The norwegians O&M is 0.11MEUR/MW, while ours is 0.22 MEUR/MW

# %%
# %reload_ext autoreload
# %autoreload 2

# %run "1_analyse_input.ipynb"
# %run "1_get_input_v2.ipynb"
# %run "2_create_scenario.ipynb"
# %run "3_time_series_output.ipynb"
# %run "4_descriptive_analysis.ipynb"
# Out:
# C:\Users\LinusLindquist\AppData\Local\Temp\ipykernel_7056\93376551.py:69: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   template = pd.date_range("2021-01-01 00:00", periods=8760, freq="H")
# 30.10 EUR/MWh
# 4300.00 EUR/MWh
# 5.21 pct. of inv.
# single_year: False
# years_covered: [2023, 2024, 2025]
# year_label: 2023-2025
# Shares over period: DK1=0.63, DK2=0.37 (sum=1.00)
# C:\Users\LinusLindquist\AppData\Local\Temp\ipykernel_7056\324016636.py:33: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   template = pd.date_range("2021-01-01 00:00", periods=8760, freq="H")
# The lenght should be 8784 and is: 8784, 8784, 8784, 8784, 8784
# i.e. an relative rise of 0.744 percent
#
# Case (M EUR)       Import  Export  Variable cost  Fixed operation costs  \
# test_new_VP           0.0     0.0          994.0                 4326.0
# ...
