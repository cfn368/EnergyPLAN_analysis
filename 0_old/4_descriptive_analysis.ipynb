# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors as mcolors
from pathlib import Path

# %reload_ext autoreload
# %autoreload 2
import var_groups, build_frames, costs, descriptive_func, fig_setup

colors = [
    "#4C72B0",  # blue
    "#55A868",  # green
    "#C44E52",  # red-ish
    "#8172B3",  # purple
    "#CCB974",  # ochre
    "#64B5CD",  # light blue
    "#8C8C8C",  # grey
    "#E17C05",  # orange
    "#76B7B2",  # teal
    "#F1CE63",  # yellow
]

# %% [markdown]
# # Initial output for paper

# %% [markdown]
# I build a freamework that can easily compose key outputs from the analysis.

# %% [markdown]
# ## 1. Decompositions

# %%
# 1. get data
dfs = [build_frames.timeseries_yearly(f) for f in var_groups.shock]
all_y = pd.concat(dfs, ignore_index=True)

# %%
source_labels = {
    Path(fname).stem: nice
    for fname, nice in var_groups.all_cases_dict.items()
}

# %% [markdown]
# ### 1.1 Production decomposition (heat and electricity)

# %%
# 2. plot
fig, ax = descriptive_func.plot_stacked_by_source(
    demand_df=all_y.loc[:, var_groups.electr + ['source']],
    title="",
    ylabel="TWh/year",
    colors=colors,
    legend_ncol=3,
    tech_labels=var_groups.tech_labels,
    source_labels=source_labels,
)

fig, ax = descriptive_func.plot_stacked_by_source(
    demand_df=all_y.loc[:, var_groups.heat + ['source']],
    title="",
    ylabel="TWh/year",
    colors=colors,
    legend_ncol=3,
    tech_labels=var_groups.tech_labels,
    source_labels=source_labels,
)

# %% [markdown]
# ## 2. Capture rates

# %% [markdown]
# Merging my hourly df with the prices I calculate the capture rates for the simulated year as
#
# $$
# \text{Capture rate}_t = \frac{p^{Pt}_t}{\bar{p}_t}
# $$
#
# where $Pt$ defines the power technology and $\bar{p}_t$ the average yearly price:

# %%
# 1. get data
dfs = [build_frames.timeseries_hourly(f) for f in var_groups.shock_descrip]
all_h = pd.concat(dfs, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[66], line 2
#       1 # 1. get data
# ----> 2 dfs = [build_frames.timeseries_hourly(f) for f in var_groups.shock_descrip]
#       3 all_h = pd.concat(dfs, ignore_index=True)
#
# File c:\Users\LinusLindquist\e-tank\E-Tank - Data\PROJEKTER\04 KERNEKRAFT\Grøn Reform beregninger\EnergyPLAN\LL_project\build_frames.py:51, in timeseries_hourly(excel_path, sheet_name)
#      47 def timeseries_hourly(excel_path, sheet_name=0):
#      48     """
#      49     Read EnergyPLAN-style Excel output and return hourly df.
#      50     """
# ---> 51     df_ = pd.read_excel('0_EP_runs/' + excel_path, sheet_name=sheet_name)
#      53     # 1. eliminate initial rows
#      54     df = df_[df_.index >= 79].copy()
#
# File c:\Users\LinusLindquist\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File c:\Users\LinusLindquist\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File c:\Users\LinusLindquist\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File c:\Users\LinusLindquist\anaconda3\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '0_EP_runs/test_new_VP_shock.xlsx,IDA2045_nuclear_flexible_dh.xlsx'

# %%
# 2. relevant
keep_cols = var_groups.electr + ['source', 'd_summer', 'hour','InMarket_Prices']
col_mask = all_h.columns.isin(keep_cols)
electr_h = all_h.loc[:, col_mask].copy()

# 3. compute agg prod
electr_h['agg_prod'] = electr_h.loc[:, var_groups.electr].sum(axis=1)

# 4. average production price
def wavg(df, weight_col):
    w = df[weight_col].to_numpy()

    mask = w > 0

    if not mask.any():
        return np.nan

    return np.average(df.loc[mask, 'InMarket_Prices'], weights=w[mask])


# 4.1 full year
y_wavg = (
    electr_h
    .groupby('source')[['InMarket_Prices', 'agg_prod']]
    .apply(wavg, weight_col='agg_prod')
)

# 4.2 year and dummy
y_wavg_d = (
    electr_h
    .groupby(['source', 'd_summer'])[['InMarket_Prices', 'agg_prod']]
    .apply(wavg, weight_col='agg_prod')
)

# 5. prices per pt
pt_wavg, pt_wavg_d = [], []

for pt in var_groups.electr:

    # 5.1 full year
    pt_ = (
        electr_h
        .groupby('source')[['InMarket_Prices', pt]]
        .apply(wavg, weight_col=pt)
    )
    pt_.name = pt
    pt_wavg.append(pt_)

    # 5.2 year and dummy
    pt_d = (
        electr_h
        .groupby(['source', 'd_summer'])[['InMarket_Prices', pt]]
        .apply(wavg, weight_col=pt)
    )
    pt_d.name = pt
    pt_wavg_d.append(pt_d)

# 6. compute capture rates
pt_wavg_df   = pd.concat(pt_wavg, axis=1)
pt_wavg_d_df = pd.concat(pt_wavg_d, axis=1)

capture_full     = pt_wavg_df.div(y_wavg, axis=0)
capture_seasonal = pt_wavg_d_df.div(y_wavg_d, axis=0)

# %% [markdown]
# ##### *Plot:*

# %%
# 8a. plot yearly
capture_full_plot = capture_full.rename(columns=var_groups.tech_labels)

descriptive_func.plot_capture_full(
    capture_full_plot,
    source_labels=source_labels,
    colors=colors,
    title='',
    plot_two=False,
    savepath="0_figs/fig3.pdf",  
    dpi=300,
    show=True,
    print_saved=True,
    rotate=False,
)
# Out:
# Saved figure: 0_figs\fig3.pdf
# ((<Figure size 1200x600 with 1 Axes>, <Axes: >), (None, None))

# %% [markdown]
# ## 3. Capacity factor

# %% [markdown]
# Similarly, I compute the capacity factor as
#
# $$
#     \text{Capacity factor}_t = \frac{\hat{y}_t^{Pt}}{y_t^{Pt}}
# $$
#
# with $\hat{y}_t^{Pt}$ as the actual production and $y_t$ as the technologically feasible:

# %% [markdown]
# ### 3.1 For VE and nuclear

# %%
# 1. get (using from #2)
keep_cols = var_groups.VE_electr + ['source', 'd_summer', 'hour']   # VE version

col_mask = all_h.columns.isin(keep_cols)
VE_h = all_h.loc[:, col_mask].copy()

# 2. compute sums
pt_sum, pt_sum_d = [], []

for pt in var_groups.VE_electr:

    pt_y = VE_h.groupby('source')[pt].sum()
    pt_y.name = pt 
    pt_sum.append(pt_y)

    pt_y_d = VE_h.groupby(['source','d_summer'])[pt].sum()
    pt_y_d.name = pt 
    pt_sum_d.append(pt_y_d)

pt_sum_df   = pd.concat(pt_sum, axis=1)
pt_sum_d_df = pd.concat(pt_sum_d, axis=1)

# 3. get capacities
caps_by_source = {
    "test_new_VP":           var_groups.test_new_VP_caps,
    "test_new_VP_shock":           var_groups.test_new_VP_shock_caps,
}

# 4. make consistent and yearly
caps_df = pd.DataFrame.from_dict(caps_by_source, orient='index')
caps_df = caps_df[var_groups.VE_electr]
caps_df = caps_df.reindex(index=pt_sum_df.index)

cap_energy_full = caps_df * 8784 

# 5. compute cap fac

# 5.1 full year
cf_full = pt_sum_df / cap_energy_full

# 5.2 d_summer
hours_d = (
    VE_h
    .groupby(['source', 'd_summer'])['hour']
    .nunique()
)

# 5.2.1 specific hours multi
caps_for_groups = caps_df.loc[
    pt_sum_d_df.index.get_level_values('source')
].to_numpy()
cap_energy_d = caps_for_groups * hours_d.to_numpy()[:, None] 

# 5.2.2 df in same format
cap_energy_d_df = pd.DataFrame(
    cap_energy_d,
    index=pt_sum_d_df.index,
    columns=pt_sum_d_df.columns,
)

# 5.2.3 seasonal capacity factor
cf_seasonal = pt_sum_d_df / cap_energy_d_df

# 6. plot
# 6.1 full-year CF: one strong color per source (plot_capture_full)
cf_full_plot = cf_full.rename(columns=var_groups.tech_labels)
descriptive_func.plot_capture_full(
    cf_full_plot, 
    plot_two=False,
    source_labels=source_labels,
    colors=colors,
    axline=False,
    title=' ',
    rotate=False,
)

# 6.2 seasonal CF: same shaded colours as before (plot_capture_seasonal)
# cf_seasonal_plot = cf_seasonal.rename(columns=var_groups.tech_labels)
# descriptive_func.plot_capture_seasonal(
#     cf_seasonal_plot,
#     source_labels=source_labels,
#     colors_input=colors,
#     plot_two=False,
#     axline=False,
#     title='VE og kernekraft: Capacity factorn (seasonal)'
# )
# Out:
# ((<Figure size 1200x600 with 1 Axes>, <Axes: title={'center': ' '}>),
#  (None, None))

# %% [markdown]
# ### 3.2 For storage caps

# %%
# 1. get (using from #2)
keep_cols = var_groups.storages + ['source', 'd_summer', 'hour']   # storage version

col_mask = all_h.columns.isin(keep_cols)
VE_h = all_h.loc[:, col_mask].copy()

# 2. compute sums
pt_sum, pt_sum_d = [], []

for pt in var_groups.storages:

    pt_y = VE_h.groupby('source')[pt].sum()
    pt_y.name = pt 
    pt_sum.append(pt_y)

    pt_y_d = VE_h.groupby(['source','d_summer'])[pt].sum()
    pt_y_d.name = pt 
    pt_sum_d.append(pt_y_d)

pt_sum_df   = pd.concat(pt_sum, axis=1)
pt_sum_d_df = pd.concat(pt_sum_d, axis=1)

# 3. get capacities
caps_by_source = {
    "test_new_VP":           var_groups.test_new_VP_caps,
    "test_new_VP_shock":           var_groups.test_new_VP_shock_caps,
}

# 4. make consistent and yearly
caps_df = pd.DataFrame.from_dict(caps_by_source, orient='index')
caps_df = caps_df[var_groups.storages]
caps_df = caps_df.reindex(index=pt_sum_df.index)

cap_energy_full = caps_df * 8784  * 1000

# 5. compute cap fac

# 5.1 full year
cf_full = pt_sum_df / cap_energy_full

# 5.2 d_summer
hours_d = (
    VE_h
    .groupby(['source', 'd_summer'])['hour']
    .nunique()
)

# 5.2.1 specific hours multi
caps_for_groups = caps_df.loc[
    pt_sum_d_df.index.get_level_values('source')
].to_numpy()
cap_energy_d = caps_for_groups * hours_d.to_numpy()[:, None]  * 1000

# 5.2.2 df in same format
cap_energy_d_df = pd.DataFrame(
    cap_energy_d,
    index=pt_sum_d_df.index,
    columns=pt_sum_d_df.columns,
)

# 5.2.3 seasonal capacity factor
cf_seasonal = pt_sum_d_df / cap_energy_d_df

# 6. plot
# 6.1 full-year CF: one strong color per source (plot_capture_full)
cf_full_plot = cf_full.rename(columns=var_groups.tech_labels)
descriptive_func.plot_capture_full(
    cf_full_plot, 
    plot_two=False,
    source_labels=source_labels,
    colors=colors,
    axline=False,
    title=' ',
    savepath="0_figs/fig4.pdf",  
    dpi=300,
    show=True,
    print_saved=True,
    rotate=False,
)
# Out:
# Saved figure: 0_figs\fig4.pdf
# ((<Figure size 1200x600 with 1 Axes>, <Axes: title={'center': ' '}>),
#  (None, None))
