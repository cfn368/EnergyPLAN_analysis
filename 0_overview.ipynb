# %% [markdown]
# # Overview
#
# *The intention is that the other notebooks then will just concern themselves, while the general considertions are specified here.*

# %% [markdown]
# **STATUS:** Comparisons for the base scenario have been made, but suddently plot function didn't work

# %% [markdown]
# ### Cases overview
#
# Often displayed against `1GWnuc (1)`, `IDA2045_Final` and `IDA2045_nuclear_flexible_dh` respectively.
#
# **Referencer:**
# 1. `IDA2045` FOA scenarie uden nuclear, kun elproducerende.
# 2. `RES` Norsk scenarie uden nuclear
# 3. `1GWnuc` Norsk scenarie med 1GW nuclear, kun elproducerende.
# 4. `IDA2045_nuclear_flexible` FOA scenarie med 1GW nuclear, kun elproducerende.
#
# **ET-stød:**
# 1. `R_1_nt` Reference scenario, no transmissions cap.
# 2. `R_1_wt` Reference scenario, KF transmissions cap.
# 3. `S_1_nt` Shock with 1GW nuclear and 2GW WS, no transmissions cap.

# %% [markdown]
# ### Q&A with JZT
#
# *Nb. remember to watch videos*
#
# **Q: How to go about the optimization?**
# - Increase (if furfill ourselves) PP-production (internalize costs of too little production).
# - Keep as is and then specify problem and associate some cost with problem.
# - Add transmission line capacity (this is what KF does, find KF numbers).
#
# **Q: Recommended simulation strategy?**
# - Technical: Do everything internally, when not sufficient, then use external market.
# - Economic: What cheapest home of foreign production, just minimize.
#
# **Q: What's up with the high 'Electricity storage'?**
# - In IDA, they are including some Norwegian capacity.
# - JZT and I go through output soon, to specify other places for changes.

# %% [markdown]
# ### FL: Output
#
# 1. Costs and it's components
# 2. Storage (split in summer/winter)

# %% [markdown]
# ### NTS
#
# - Seems very important whether trade is allowed and how
